# %% [markdown]
# """
# This script initializes the finetuning pipeline for Large Language Models (LLMs)
# using the LLaMA-Factory framework.
#
# It is designed as a general entry point for instruction tuning tasks and supports
# popular LLMs such as LLaMA, Baichuan, Qwen, ChatGLM, and others.
#
# Key functionalities include:
# - Hugging Face CLI authentication
# - Google Drive mounting (Colab)
# - Cloning the LLaMA-Factory repository
# - Installing dependencies
# - Disabling Weights & Biases (W&B) tracking
# - Launching the Gradio-based web UI for configuration and training
#
# Replace directory paths and Hugging Face tokens as needed.
# """

# %%
# !git config --global credential.helper store

# %%
# !huggingface-cli login

# %%
# !git clone https://github.com/hiyouga/LLaMA-Factory.git
# Out:
# fatal: destination path 'LLaMA-Factory' already exists and is not an empty directory.

# %%
# %cd LLaMA-Factory

# %%
# !pwd

# %%
# !pip install -e ".[torch,metrics]"

# %%
# !pip install bitsandbytes

# %%
import os
os.environ["WANDB_DISABLED"] = "true"

# %%
# !GRADIO_SHARE=1 llamafactory-cli webui
